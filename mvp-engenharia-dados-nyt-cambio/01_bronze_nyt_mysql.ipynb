# %%
df_bronze = (spark.read
    .option("header", True)
    .option("inferSchema", True)
    .csv("/Volumes/workspace/default/nyt_articles/nyt_articles_2026_09_13.csv"))

print(f"Linhas carregadas: {df_bronze.count()}")
df_bronze.printSchema()
df_bronze.display()

df_bronze.write.mode("overwrite").saveAsTable("workspace.default.bronze_nyt_articles")
